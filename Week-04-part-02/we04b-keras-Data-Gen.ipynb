# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# **Create a notebook that pre-processes this data for model fitting**
#
# **In your notebook, analyze and process your chosen data. Identify your target variable and your input variables. Be sure to include details about what you observed, what changes you are making, how you are making these changes, and why you are making these changes. For instance, you might have a section in your notebook where you analyze the data to identify issues with missing data. Present your results, then argue for what (if anything) you need to do and why, and then show clearly the steps you undertook to accomplish this. Save the results into csv files (these files should therefore be pre-processed and ready for model fitting. Later model fitting notebooks should not need data manipulation/processing.**

# %% [markdown]
# ## Introduction
#
# I have chosen this [data source](https://www.kaggle.com/datasets/subhajeetdas/car-acceptability-classification-dataset?select=car.data) for the assignment -
#
#
# ### Brief overview of the data
#
# The data set consists of 7 attributes of 1728 used cars.
#
# ### Attribute description
# * Car Acceptability Classification Dataset
#
# 1. Buying_Price - Categorical Data [vhigh, high, med, low]
# 2. Maintenance_Price - Categorical Data [vhigh, high, med, low]
# 3. No_of_Doors - Categorical Data [2, 3, 4, 5more]
# 4. Person_Capacity - Categorical Data [2, 4, more]
# 5. Size_of_Luggage - Categorical Data [small, med, big]
# 6. Safety - Categorical Data [low, med, high]
# 7. Car_Acceptability - Categorical Data [unacc, acc, good, vgood]
#
#
# ## Goal
#
# The goal of this analysis is to predict the car acceptability status by developing a predictive model using Keras.
#
# * The attribute "Car_Acceptability" from the list of 7 attributes is used as the target variable to classify a Car into **unacceptable, acceptable, good and very good** categories.
# * The remaining 6 attributes are used as predictors.

# %% [markdown]
# ## Importing the required libraries

# %%
# import numpy and pandas libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.impute import SimpleImputer

# set random seed to ensure that results are repeatable
np.random.seed(86089106)

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv("car.csv")
df.head(3)
# Out:
#   Buying_Price Maintenance_Price No_of_Doors Person_Capacity Size_of_Luggage
# 0        vhigh             vhigh           2               2           small  \
# 1        vhigh             vhigh           2               2           small
# 2        vhigh             vhigh           2               2           small
#
#   Safety Car_Acceptability
# 0    low             unacc
# 1    med             unacc
# 2   high             unacc

# %% [markdown]
# ## Inspect the data

# %%
df.describe()
# Out:
#        Buying_Price Maintenance_Price No_of_Doors Person_Capacity
# count          1728              1728        1728            1728  \
# unique            4                 4           4               3
# top           vhigh             vhigh           2               2
# freq            432               432         432             576
#
#        Size_of_Luggage Safety Car_Acceptability
# count             1728   1728              1728
# unique               3      3                 4
# top              small    low             unacc
# freq               576    576              1210

# %%
# Check the missing values by summing the total na's for each variable
df.isna().sum()
# Out:
# Buying_Price         0
# Maintenance_Price    0
# No_of_Doors          0
# Person_Capacity      0
# Size_of_Luggage      0
# Safety               0
# Car_Acceptability    0
# dtype: int64

# %%
#clear any white spaces before starting to analyze.
df.columns = [s.strip() for s in df.columns] 
df.columns
# Out:
# Index(['Buying_Price', 'Maintenance_Price', 'No_of_Doors', 'Person_Capacity',
#        'Size_of_Luggage', 'Safety', 'Car_Acceptability'],
#       dtype='object')

# %% [markdown]
# ## Using one-hot encoding to replace categorical variables

# %%
df['Buying_Price'] = df['Buying_Price'].replace({1: "low", 2: 'med', 3: 'high', 4: 'vhigh'})

df['Maintenance_Price'] = df['Maintenance_Price'].replace({1: "low", 2: 'med', 3: 'high', 4: 'vhigh'})

df['No_of_Doors'] = df['No_of_Doors'].replace({1: '2', 2: '3', 3: '4', 4: '5more'})

df['Person_Capacity'] = df['Person_Capacity'].replace({1: '2', 2: '4', 3: 'more'})

df['Size_of_Luggage'] = df['Size_of_Luggage'].replace({1: 'small', 2: 'med', 3: 'big'})

df['Safety'] = df['Safety'].replace({1: 'low', 2: 'med', 3: 'high'})

#df['Car_Acceptability'] = df['Car_Acceptability'].replace({1: 'unacc', 2: 'acc', 3: 'good', 4: 'vgood'})

# %%
buying_price_dummies = pd.get_dummies(df['Buying_Price'], prefix='Buying_Price', drop_first=False)
df = df.join(buying_price_dummies)

maintenance_price_dummies = pd.get_dummies(df['Maintenance_Price'], prefix='Maintenance_Price', drop_first=False)
df = df.join(maintenance_price_dummies)

no_of_doors_dummies = pd.get_dummies(df['No_of_Doors'], prefix='No_of_Doors', drop_first=False)
df = df.join(no_of_doors_dummies)

person_capacity_dummies = pd.get_dummies(df['Person_Capacity'], prefix='Person_Capacity', drop_first=False)
df = df.join(person_capacity_dummies)

size_of_luggage_dummies = pd.get_dummies(df['Size_of_Luggage'], prefix='Size_of_Luggage', drop_first=False)
df = df.join(size_of_luggage_dummies)

safety_dummies = pd.get_dummies(df['Safety'], prefix='Safety', drop_first=False)
df = df.join(safety_dummies)

#car_acceptability_dummies = pd.get_dummies(df['Car_Acceptability'], prefix='Car_Acceptability', drop_first=False)
#df = df.join(car_acceptability_dummies)

# %%
#Inspecting the data after the above changes
df.head(5)
# Out:
#   Buying_Price Maintenance_Price No_of_Doors Person_Capacity Size_of_Luggage
# 0        vhigh             vhigh           2               2           small  \
# 1        vhigh             vhigh           2               2           small
# 2        vhigh             vhigh           2               2           small
# 3        vhigh             vhigh           2               2             med
# 4        vhigh             vhigh           2               2             med
#
#   Safety Car_Acceptability  Buying_Price_high  Buying_Price_low
# 0    low             unacc              False             False  \
# 1    med             unacc              False             False
# 2   high             unacc              False             False
# 3    low             unacc              False             False
# 4    med             unacc              False             False
#
#    Buying_Price_med  ...  No_of_Doors_5more  Person_Capacity_2
# 0             False  ...              False               True  \
# 1             False  ...              False               True
# 2             False  ...              False               True
# 3             False  ...              False               True
# 4             False  ...              False               True
#
#    Person_Capacity_4  Person_Capacity_more  Size_of_Luggage_big
# 0              False                 False                False  \
# 1              False                 False                False
# 2              False                 False                False
# 3              False                 False                False
# 4              False                 False                False
#
#    Size_of_Luggage_med  Size_of_Luggage_small  Safety_high  Safety_low
# 0                False                   True        False        True  \
# 1                False                   True        False       False
# 2                False                   True         True       False
# 3                 True                  False        False        True
# 4                 True                  False        False       False
#
#    Safety_med
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#
# [5 rows x 28 columns]

# %%
# Dropping unnessary columns 
df = df.drop(['Buying_Price', 'Maintenance_Price', 'No_of_Doors', 'Person_Capacity',
       'Size_of_Luggage', 'Safety'], axis=1)

# %%
# generate a basic summary of the datal
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car_Acceptability        1728 non-null   object
#  1   Buying_Price_high        1728 non-null   bool
#  2   Buying_Price_low         1728 non-null   bool
#  3   Buying_Price_med         1728 non-null   bool
#  4   Buying_Price_vhigh       1728 non-null   bool
#  5   Maintenance_Price_high   1728 non-null   bool
#  6   Maintenance_Price_low    1728 non-null   bool
#  7   Maintenance_Price_med    1728 non-null   bool
#  8   Maintenance_Price_vhigh  1728 non-null   bool
#  9   No_of_Doors_2            1728 non-null   bool
#  10  No_of_Doors_3            1728 non-null   bool
#  11  No_of_Doors_4            1728 non-null   bool
#  12  No_of_Doors_5more        1728 non-null   bool
#  13  Person_Capacity_2        1728 non-null   bool
#  14  Person_Capacity_4        1728 non-null   bool
#  15  Person_Capacity_more     1728 non-null   bool
#  16  Size_of_Luggage_big      1728 non-null   bool
#  17  Size_of_Luggage_med      1728 non-null   bool
#  18  Size_of_Luggage_small    1728 non-null   bool
#  19  Safety_high              1728 non-null   bool
#  20  Safety_low               1728 non-null   bool
#  21  Safety_med               1728 non-null   bool
# dtypes: bool(21), object(1)
# memory usage: 49.1+ KB

# %%
# generate a statistical summary of the numeric value in the data
df.describe()
# Out:
#        Car_Acceptability Buying_Price_high Buying_Price_low Buying_Price_med
# count               1728              1728             1728             1728  \
# unique                 4                 2                2                2
# top                unacc             False            False            False
# freq                1210              1296             1296             1296
#
#        Buying_Price_vhigh Maintenance_Price_high Maintenance_Price_low
# count                1728                   1728                  1728  \
# unique                  2                      2                     2
# top                 False                  False                 False
# freq                 1296                   1296                  1296
#
#        Maintenance_Price_med Maintenance_Price_vhigh No_of_Doors_2  ...
# count                   1728                    1728          1728  ...  \
# unique                     2                       2             2  ...
# top                    False                   False         False  ...
# freq                    1296                    1296          1296  ...
#
#        No_of_Doors_5more Person_Capacity_2 Person_Capacity_4
# count               1728              1728              1728  \
# unique                 2                 2                 2
# top                False             False             False
# freq                1296              1152              1152
#
#        Person_Capacity_more Size_of_Luggage_big Size_of_Luggage_med
# count                  1728                1728                1728  \
# unique                    2                   2                   2
# top                   False               False               False
# freq                   1152                1152                1152
#
#        Size_of_Luggage_small Safety_high Safety_low Safety_med
# count                   1728        1728       1728       1728
# unique                     2           2          2          2
# top                    False       False      False      False
# freq                    1152        1152       1152       1152
#
# [4 rows x 22 columns]

# %% [markdown]
# ### Properteis and observations of cleaned data

# %%
df.head(5)
# Out:
#   Car_Acceptability  Buying_Price_high  Buying_Price_low  Buying_Price_med
# 0             unacc              False             False             False  \
# 1             unacc              False             False             False
# 2             unacc              False             False             False
# 3             unacc              False             False             False
# 4             unacc              False             False             False
#
#    Buying_Price_vhigh  Maintenance_Price_high  Maintenance_Price_low
# 0                True                   False                  False  \
# 1                True                   False                  False
# 2                True                   False                  False
# 3                True                   False                  False
# 4                True                   False                  False
#
#    Maintenance_Price_med  Maintenance_Price_vhigh  No_of_Doors_2  ...
# 0                  False                     True           True  ...  \
# 1                  False                     True           True  ...
# 2                  False                     True           True  ...
# 3                  False                     True           True  ...
# 4                  False                     True           True  ...
#
#    No_of_Doors_5more  Person_Capacity_2  Person_Capacity_4
# 0              False               True              False  \
# 1              False               True              False
# 2              False               True              False
# 3              False               True              False
# 4              False               True              False
#
#    Person_Capacity_more  Size_of_Luggage_big  Size_of_Luggage_med
# 0                 False                False                False  \
# 1                 False                False                False
# 2                 False                False                False
# 3                 False                False                 True
# 4                 False                False                 True
#
#    Size_of_Luggage_small  Safety_high  Safety_low  Safety_med
# 0                   True        False        True       False
# 1                   True        False       False        True
# 2                   True         True       False       False
# 3                  False        False        True       False
# 4                  False        False       False        True
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Spliting the data for training and testing (data partitoning 70/30)

# %%
train_df, test_df = train_test_split(df, test_size=0.3)

# %% [markdown]
# ### Seperating the predictors and traget variables

# %%
target = 'Car_Acceptability'
predictors = list(df.columns)
predictors.remove(target)

# %% [markdown]
# ### Saving the datasets for testing and training

# %%
X_train = train_df[predictors]
y_train = train_df[target]
X_test = test_df[predictors]
y_test = test_df[target]

# %%
X_train.isna().sum()
# Out:
# Buying_Price_high          0
# Buying_Price_low           0
# Buying_Price_med           0
# Buying_Price_vhigh         0
# Maintenance_Price_high     0
# Maintenance_Price_low      0
# Maintenance_Price_med      0
# Maintenance_Price_vhigh    0
# No_of_Doors_2              0
# No_of_Doors_3              0
# No_of_Doors_4              0
# No_of_Doors_5more          0
# Person_Capacity_2          0
# Person_Capacity_4          0
# Person_Capacity_more       0
# Size_of_Luggage_big        0
# Size_of_Luggage_med        0
# Size_of_Luggage_small      0
# Safety_high                0
# Safety_low                 0
# Safety_med                 0
# dtype: int64

# %%
X_train.head(3)
# Out:
#      Buying_Price_high  Buying_Price_low  Buying_Price_med
# 965              False             False              True  \
# 516               True             False             False
# 160              False             False             False
#
#      Buying_Price_vhigh  Maintenance_Price_high  Maintenance_Price_low
# 965               False                   False                  False  \
# 516               False                   False                  False
# 160                True                    True                  False
#
#      Maintenance_Price_med  Maintenance_Price_vhigh  No_of_Doors_2
# 965                  False                     True          False  \
# 516                  False                     True          False
# 160                  False                    False          False
#
#      No_of_Doors_3  ...  No_of_Doors_5more  Person_Capacity_2
# 965          False  ...               True              False  \
# 516          False  ...               True               True
# 160           True  ...              False              False
#
#      Person_Capacity_4  Person_Capacity_more  Size_of_Luggage_big
# 965              False                  True                False  \
# 516              False                 False                False
# 160              False                  True                 True
#
#      Size_of_Luggage_med  Size_of_Luggage_small  Safety_high  Safety_low
# 965                False                   True         True       False  \
# 516                 True                  False        False        True
# 160                False                  False        False       False
#
#      Safety_med
# 965       False
# 516       False
# 160        True
#
# [3 rows x 21 columns]

# %%
y_train.head(3)
# Out:
# 965      acc
# 516    unacc
# 160    unacc
# Name: Car_Acceptability, dtype: object

# %%
X_test.head(3)
# Out:
#       Buying_Price_high  Buying_Price_low  Buying_Price_med
# 1217              False             False              True  \
# 1312              False              True             False
# 840                True             False             False
#
#       Buying_Price_vhigh  Maintenance_Price_high  Maintenance_Price_low
# 1217               False                   False                   True  \
# 1312               False                   False                  False
# 840                False                   False                   True
#
#       Maintenance_Price_med  Maintenance_Price_vhigh  No_of_Doors_2
# 1217                  False                    False          False  \
# 1312                  False                     True           True
# 840                   False                    False          False
#
#       No_of_Doors_3  ...  No_of_Doors_5more  Person_Capacity_2
# 1217           True  ...              False               True  \
# 1312          False  ...              False              False
# 840           False  ...               True               True
#
#       Person_Capacity_4  Person_Capacity_more  Size_of_Luggage_big
# 1217              False                 False                False  \
# 1312               True                 False                 True
# 840               False                 False                False
#
#       Size_of_Luggage_med  Size_of_Luggage_small  Safety_high  Safety_low
# 1217                False                   True         True       False  \
# 1312                False                  False        False       False
# 840                  True                  False        False        True
#
#       Safety_med
# 1217       False
# 1312        True
# 840        False
#
# [3 rows x 21 columns]

# %%
y_test.head(3)
# Out:
# 1217    unacc
# 1312      acc
# 840     unacc
# Name: Car_Acceptability, dtype: object

# %%
#saving the training and testing data to .csv files
X_train.to_csv('car-X-train_data.csv', index=False)
y_train.to_csv('car-y-train_data.csv', index=False)
X_test.to_csv('car-X-test_data.csv', index=False)
y_test.to_csv('car-y-test_data.csv', index=False)

# %% [markdown]
# ## Conclusion
#
# In this notebook, I used the techniques discussed in the class to preprocess the dataset. The training and test data are saved to the .csv files which can be used for modelling.
